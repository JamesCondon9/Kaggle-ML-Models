# %%
import pandas as pd
import matplotlib.pyplot as plt
import dtale

df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

women = df_train.loc[df_train.Sex == 'female']["Survived"] # Stores binary values of 

rate_women = sum(women) / len(women)
print(f"% of women who survived: {rate_women}")

men = df_train.loc[df_train.Sex == 'male']["Survived"] # Stores binary values of 

rate_men = sum(men) / len(men)
print(f"% of men who survived: {rate_men}")


dtale.show(df_train)
# Out:
# % of women who survived: 0.7420382165605095
# % of men who survived: 0.18890814558058924
#         <iframe
#             width="100%"
#             height="475"
#             src="http://HP-Spectre-Laptop:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
## Classifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeRegressor
y = df_train["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(df_train[features])
X_test = pd.get_dummies(df_test[features])

model = RandomForestClassifier(random_state=1)

param_grid = {
    'n_estimators': [200, 500, 1000],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [2,3,4,5],
    'criterion': ['gini', 'entropy']
}

CV_model = GridSearchCV(estimator=model, param_grid=param_grid)

CV_model.fit(X, y)
predictions = CV_model.predict(X_test)

# %%
CV_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'n_estimators': 500}

# %%
## Model Evaluation
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=2)
skf.split()

dtale.show(df_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 ## Model Evaluation
# ...

# %%
## Submission saving code

output = pd.DataFrame({'PassengerId': df_test.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Submission saved!")
# Out:
# Submission saved!
